# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r"D:\data science\internship\1207 Assessment 3\1207 Assessment 3\Airbnb_Dataset.csv")
df2= pd.read_csv(r"D:\data science\internship\1207 Assessment 3\1207 Assessment 3\HR_Dataset.csv")

# %%
df1
# Out:
#         id                                              name  host_id  \
# 0     2539                Clean & quiet apt home by the park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                   Cozy Entire Floor of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ..     ...                                               ...      ...
# 244  61492          Exclusive Room with Private Bath in  LES   297769
# 245  61509               Quiet, clean midtown apt w. elevato    23619
# 246  62095                 BK Sweet Suite w/Kitchen&FullBath   281764
# 247  62427               Great East Village Apartment Rental   303882
# 248  62430                     BROWNSTONE SUNDRENCHED BEAUTY   197755
#
#         host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# ...

# %%
df1.shape
# Out:
# (249, 16)

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of         id                                              name  host_id  \
# 0     2539                Clean & quiet apt home by the park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                   Cozy Entire Floor of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ..     ...                                               ...      ...
# 244  61492          Exclusive Room with Private Bath in  LES   297769
# 245  61509               Quiet, clean midtown apt w. elevato    23619
# 246  62095                 BK Sweet Suite w/Kitchen&FullBath   281764
# 247  62427               Great East Village Apartment Rental   303882
# 248  62430                     BROWNSTONE SUNDRENCHED BEAUTY   197755
#
#         host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# ...

# %%
df1.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       7
# reviews_per_month                 7
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
missing_last_review_rows = df1[df1['last_review'].isna()]

# %%
missing_last_review_rows
# Out:
#         id                                               name  host_id  \
# 2     3647                THE VILLAGE OF HARLEM....NEW YORK !     4632
# 19    7750                  Huge 2 BR Upper East  Cental Park    17985
# 26    8700  Magnifique Suite au N de Manhattan - vue Cloitres    26394
# 36   11452                        Clean and Quiet in Brooklyn     7355
# 38   11943                          Country space in the city    45445
# 193  51438                1 Bedroom in 2 Bdrm Apt- Upper East   236421
# 204  54466                Beautiful Uptown Manhattan apartmnt   253385
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 19              Sing           Manhattan         East Harlem  40.79685
# 26   Claude & Sophie           Manhattan              Inwood  40.86754
# 36                Vt            Brooklyn  Bedford-Stuyvesant  40.68876
# ...

# %%
df1['last_review'].describe
# Out:
# <bound method NDFrame.describe of 0      10/19/2018
# 1       5/21/2019
# 2             NaN
# 3        7/5/2019
# 4      11/19/2018
#           ...
# 244     6/23/2019
# 245     4/30/2019
# 246     6/14/2019
# 247     5/26/2019
# 248     6/22/2019
# Name: last_review, Length: 249, dtype: object>

# %%
df1["last_review"] = pd.to_datetime(df1["last_review"],errors="coerce")

# %%
df1["last_review"].info
# Out:
# <bound method Series.info of 0     2018-10-19
# 1     2019-05-21
# 2            NaT
# 3     2019-07-05
# 4     2018-11-19
#          ...
# 244   2019-06-23
# 245   2019-04-30
# 246   2019-06-14
# 247   2019-05-26
# 248   2019-06-22
# Name: last_review, Length: 249, dtype: datetime64[ns]>

# %%
avg_date = df1["last_review"].mean()

# %%
avg_date
# Out:
# Timestamp('2018-10-09 06:26:46.611570176')

# %%
df1["last_review"].fillna(avg_date, inplace=True)

# %%
df1
# Out:
#         id                                              name  host_id  \
# 0     2539                Clean & quiet apt home by the park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                   Cozy Entire Floor of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ..     ...                                               ...      ...
# 244  61492          Exclusive Room with Private Bath in  LES   297769
# 245  61509               Quiet, clean midtown apt w. elevato    23619
# 246  62095                 BK Sweet Suite w/Kitchen&FullBath   281764
# 247  62427               Great East Village Apartment Rental   303882
# 248  62430                     BROWNSTONE SUNDRENCHED BEAUTY   197755
#
#         host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# ...

# %%
avg_review = df1["reviews_per_month"].mean()

# %%
avg_review
# Out:
# 1.0916528925619833

# %%
df1["reviews_per_month"].fillna(avg_review, inplace= True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13372\363759367.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["reviews_per_month"].fillna(avg_review, inplace= True)

# %%
df1["reviews_per_month"]
# Out:
# 0      0.210000
# 1      0.380000
# 2      1.091653
# 3      4.640000
# 4      0.100000
#          ...
# 244    1.800000
# 245    0.900000
# 246    2.300000
# 247    0.580000
# 248    2.130000
# Name: reviews_per_month, Length: 249, dtype: float64

# %%
df1.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df1
# Out:
#         id                                              name  host_id  \
# 0     2539                Clean & quiet apt home by the park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                   Cozy Entire Floor of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ..     ...                                               ...      ...
# 244  61492          Exclusive Room with Private Bath in  LES   297769
# 245  61509               Quiet, clean midtown apt w. elevato    23619
# 246  62095                 BK Sweet Suite w/Kitchen&FullBath   281764
# 247  62427               Great East Village Apartment Rental   303882
# 248  62430                     BROWNSTONE SUNDRENCHED BEAUTY   197755
#
#         host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# ...

# %%
avg_price= df1.groupby("neighbourhood_group")["price"].mean().reset_index()

# %%
avg_price
# Out:
#   neighbourhood_group       price
# 0               Bronx   42.500000
# 1            Brooklyn  137.459459
# 2           Manhattan  151.846774
# 3              Queens  146.090909
# 4       Staten Island   70.000000

# %%
plt.figure(figure=(10,6))
sns.barplot(data=avg_price, x = "neighbourhood_group", y= "price", palette='viridis')
plt.title("average price in Neighbourhood")
plt.xlabel("neighbourhood_group")
plt.ylabel("price")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13372\1529464848.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_price, x = "neighbourhood_group", y= "price", palette='viridis')

# %%
# As per the Bar chart we can notice that the prices of the AirBnb properties in Manhttan are the costliest followed by Queens and Brooklyn, 
# while least prices are seen in Bronx.

# %%
unique_rooms = df1["room_type"].unique()
unique_rooms
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
room_counts = df1["room_type"].value_counts()
room_counts
# Out:
# room_type
# Entire home/apt    134
# Private room       113
# Shared room          2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
colors = ("green", "orange", "yellow", "red")
plt.pie(room_counts, labels=room_counts.index, autopct='%1.1f%%', colors=colors)
plt.title("types of properties")
plt.show()

# %%
# The aboce Pie chart shows that most of the hosts/owners own the entire home/apt which is 53.9%, 
# the second priority by owners/hosts is given to theprivate room,
# Shared room are used least.

# %%
room_price= df1.groupby("room_type")["price"].mean().reset_index()
room_price
# Out:
#          room_type       price
# 0  Entire home/apt  188.574627
# 1     Private room   92.345133
# 2      Shared room   72.500000

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data= room_price, x ="room_type", y ="price")
plt.title("Average Prices Per Rooms", fontsize= 16, fontweight= "bold")
plt.xlabel("Room Types", fontsize= 12, fontweight= "bold")
plt.ylabel("Prices", fontsize= 12, fontweight= "bold")
plt.show()

# %%
# By this Violine Chart we can easily see that the getting an entire room is the costliest, and shared rooms are the cheapest.

# %%
reviews= df1.groupby("neighbourhood")["number_of_reviews"].mean().reset_index()
reviews
# Out:
#                 neighbourhood  number_of_reviews
# 0          Bedford-Stuyvesant          94.647059
# 1                 Boerum Hill          23.000000
# 2            Brooklyn Heights          25.000000
# 3                    Bushwick         106.200000
# 4             Carroll Gardens         191.500000
# 5                     Chelsea         125.000000
# 6                   Chinatown         116.333333
# 7                Clinton Hill         166.777778
# 8                 Cobble Hill         113.000000
# 9               Crown Heights          53.000000
# 10                      DUMBO          14.000000
# 11           Ditmars Steinway          17.000000
# 12              East Flatbush         238.000000
# 13                East Harlem         107.857143
# 14               East Village          96.450000
# 15         Financial District         114.000000
# 16                   Flatbush           8.000000
# 17          Flatiron District         108.000000
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data= reviews, x= "neighbourhood", y= "number_of_reviews")
plt.title("Outlighieng Neighbourhoods", fontsize=16, fontweight = "bold")
plt.xlabel("Neighbourhood", fontsize=12, fontweight = "bold")
plt.ylabel("Outlieghing Reviews", fontsize=12, fontweight = "bold")
plt.xticks(rotation= 90)
plt.show()

# %%
# As per the chart the observation is that there are only two outlieghing review giving Neighbourhoods are there,
# they are East Flatbush and Long Island city.

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(data=df1, x="room_type", y="minimum_nights", color= "green")
plt.title("Nights Per Room Tyoe", fontsize=16, fontweight= "bold")
plt.xlabel("Type of room", fontsize=12, fontweight= "bold")
plt.ylabel("Night Stay", fontsize=12, fontweight= "bold")
plt.show()
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 35.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 44.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\HP\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# We can observe that in entire home you can stay longer and for the short durations as well.
# In private rooms short and medium terms of stay plan.
# While in shared rooms you can stay not more then around 5 days.

# %%
df2
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df2.drop(["MaritalStatusID", "FromDiversityJobFairID", "MarriedID", "GenderID"], axis=1, inplace=True)
df2
# Out:
#                 Employee_Name  EmpID  EmpStatusID  DeptID  PerfScoreID  \
# 0         Adinolfi, Wilson  K  10026            1       5            4
# 1    Ait Sidi, Karthikeyan     10084            5       3            3
# 2           Akinkuolie, Sarah  10196            5       5            3
# 3                Alagbe,Trina  10088            1       5            3
# 4            Anderson, Carol   10069            5       5            3
# ..                        ...    ...          ...     ...          ...
# 306            Woodson, Jason  10135            1       5            3
# 307        Ybarra, Catherine   10301            5       5            1
# 308          Zamora, Jennifer  10010            1       3            4
# 309               Zhou, Julia  10043            1       3            3
# 310             Zima, Colleen  10271            1       5            3
#
#      Salary  Termd  PositionID                  Position State  ...  \
# ...

# %%
df2.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'EmpStatusID', 'DeptID', 'PerfScoreID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Department', y='Salary', data=df2, estimator=np.mean)
plt.title('Average Salary by Department')
plt.xticks(rotation=45)
plt.ylabel('Average Salary')
plt.xlabel('Department')
plt.show()

# %%
# Here we can observe that executive officers are earning the most and least is earned by production deparment.
# However the earning rate doesn't have much difference among all the departments except for Executive officers.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='TermReason', hue='Department', data=df2)
plt.title('Termination Reasons by Department')
plt.ylabel('Count of Terminations')
plt.xlabel('Termination Reason')
plt.legend(title='Department')
plt.show()

# %%
# most of the employees left the company as they got another position. 
# And the second major reason was because they were not happy.

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='ManagerName', y='PerformanceScore', data=df2)
plt.title('Performance Score Distribution by Manager')
plt.xlabel('Manager Name')
plt.ylabel('Performance Score')
plt.xticks(rotation=45)
plt.show()

# %%
# Most of the managers fully meets the expectation.
# There are three managers who might be not abe to perform very well.
# And there are some who needs to improve.

# %%
absences_pivot = df2.pivot_table(values='Absences', index='Department', aggfunc='sum')

plt.figure(figsize=(10, 6))
sns.heatmap(absences_pivot, annot=True, cmap='YlGnBu', cbar=True, fmt='g')
plt.title('Heatmap of Total Absences by Department')
plt.xlabel('Department ID')
plt.ylabel('Total Absences')
plt.show()

# %%
# By this we can observe that the employees of production  department are absent oftenly.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Salary', y='DaysLateLast30', data=df2, hue='RecruitmentSource', palette='viridis', s=100)
plt.title('Salary vs. Days Late')
plt.xlabel('Salary')
plt.ylabel('Days Late in Last 30 Days')
plt.legend(title='Recruitment Source', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()
plt.show()
